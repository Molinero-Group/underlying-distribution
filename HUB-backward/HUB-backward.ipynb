# %%
import os
from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/My Drive/Public/underlying_distribution/HUB-backward
cwd = os.getcwd() # Get the current working directory
print("Current working directory: {0}\n\n".format(cwd))

# %run HUB-backward.py
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Public/underlying_distribution/HUB-backward
# Current working directory: /content/drive/My Drive/Public/underlying_distribution/HUB-backward
#
#
# In the HUB-backward code we obtain the differential freezing spectrum (n_m) that better fits the target data.
