# %%
import os
from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/My Drive/Public/underlying_distribution/HUB-forward
cwd = os.getcwd() # Get the current working directory
print("Current working directory: {0}\n\n".format(cwd))

# %run HUB-forward.py
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Public/underlying_distribution/HUB-forward
# Current working directory: /content/drive/My Drive/Public/underlying_distribution/HUB-forward
#
#
# In the HUB-forward code we propose an underlying distribution (probability distribution function), and get the fraction of frozen droplets (fice) and the cumulative freezing spectrum (Nm).
# Enter below the input parameters:
# Number of droplets (10-10000): 2
# Number of droplets (10-10000): 5000
# Number of concentrations (5-9): 5
# Number of subpopulations (1, 2 or 3): 2
# Most likely freezing temperature #1 (in Celsius): -12
# Spread #1: 0.5
# Most likely freezing temperature #2 (in Celsius): -4
# Spread #2: 0.1
# Weight for subpopulation #2: 0.001
#
# ################### Summary
# Sample 5 concentrations with 5000 droplets each.
# Underlying distribution composed of 2 subpopulations of INs with Tmode1= -12.0^oC, spread1=0.5, weight1=0.999, Tmode2=-4.0^oC, spread2=0.1, weight2=0.001
#
# ################### Generating the data
# 10^0 INs per droplet
# 10^1 INs per droplet
# 10^2 INs per droplet
# 10^3 INs per droplet
# 10^4 INs per droplet
# Done!
#
# ################### Plotting the fraction of frozen droplets...
#
# ################### Plotting the cumulative freezing spectrum...
# Density of the initial suspension is 1e-3 grams/1e-3 liters and the droplet volume is 0.1*1e-6 liters.
# Do you want to change the mass of the particles and volume in the initial suspension and droplet volume (use the format 1e3, 1e-3)? Yes or No?: No
#
# ################### Done!
# Check for files in your directory.
